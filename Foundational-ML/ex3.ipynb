# %% [markdown]
# # Case Study
# **A university monitors electricity usage (in units) of 4 hostels over 7 days(Mon-Sun)**
# ##
# **Array-Name:Electricity**
# ##
# **Shape(4,7)**
# ##
# **Rows:Hostels(H1,H2,H3,H4)**
# ##
# **Cols:Days(Mon-Sun)**

# %%
import numpy as np

# %% [markdown]
# # Task A1

# %%
arr=np.random.randint(120,650,(4,7))

# %%
print(arr)
# Out:
# [[193 527 507 404 423 379 221]
#  [297 314 124 370 247 309 403]
#  [509 515 556 576 470 630 509]
#  [127 537 193 579 319 417 375]]

# %% [markdown]
# # Task A2

# %%
print(arr.shape)
print(arr.ndim)
print(arr.size)
print(arr.dtype)
# Out:
# (4, 7)
# 2
# 28
# int32

# %% [markdown]
# # Task B1

# %%
avg_usage=np.mean(arr,axis=1)
max_usage=np.max(arr,axis=1)
highest_avg=np.max(avg_usage)

# %%
print(avg_usage)
print(max_usage)
print(highest_avg)
# Out:
# [379.14285714 294.85714286 537.85714286 363.85714286]
# [527 403 630 579]
# 537.8571428571429

# %% [markdown]
# # Task B2

# %%
total_consumption=np.sum(arr,axis=0)
highest_total=np.max(total_consumption)

# %%
print(total_consumption)
print(highest_total)
# Out:
# [1126 1893 1380 1929 1459 1735 1508]
# 1929

# %% [markdown]
# ## Task C

# %%
penalized_usage=np.where(arr>550,arr*1.20,arr)
print(penalized_usage)
# Out:
# [[193.  527.  507.  404.  423.  379.  221. ]
#  [297.  314.  124.  370.  247.  309.  403. ]
#  [509.  515.  667.2 691.2 470.  756.  509. ]
#  [127.  537.  193.  694.8 319.  417.  375. ]]

# %% [markdown]
# ## Task D1

# %%
compare=np.where(avg_usage.reshape(4,1)>arr,True,False)
print(compare)
# Out:
# [[ True False False False False  True  True]
#  [False False  True False  True False False]
#  [ True  True False False  True False  True]
#  [ True False  True False  True False False]]

# %% [markdown]
# ## Task E1

# %%
new=np.reshape(arr,(1,28))
print(new)
# Out:
# [[193 527 507 404 423 379 221 297 314 124 370 247 309 403 509 515 556 576
#   470 630 509 127 537 193 579 319 417 375]]

# %% [markdown]
# ## Task E2

# %%
new1=np.reshape(arr,(2,14))
print(new1)
# Out:
# [[193 527 507 404 423 379 221 297 314 124 370 247 309 403]
#  [509 515 556 576 470 630 509 127 537 193 579 319 417 375]]

# %% [markdown]
# ## Task F1

# %%
ref_backup=arr
safe_backup=arr.copy()

# %%
arr[0,0]=0

# %%
print(arr)
print(ref_backup)
print(safe_backup)
# Out:
# [[  0 527 507 404 423 379 221]
#  [297 314 124 370 247 309 403]
#  [509 515 556 576 470 630 509]
#  [127 537 193 579 319 417 375]]
# [[  0 527 507 404 423 379 221]
#  [297 314 124 370 247 309 403]
#  [509 515 556 576 470 630 509]
#  [127 537 193 579 319 417 375]]
# [[193 527 507 404 423 379 221]
#  [297 314 124 370 247 309 403]
#  [509 515 556 576 470 630 509]
#  [127 537 193 579 319 417 375]]
