# %% [markdown]
# **Case Study**

# %% [markdown]
# you are managing the electronics section of a store. You need to track the sales of **3 products**:Headphones,Smartwatches,and Speakers
# over **4 days** (Monday to Thursday)
# Row 0:Headphones
# Row 1:Smartwatches
# Row 2:Speakers

# %%
import numpy as np

# %%
a=np.array([1500,3000,5000])

# %%
b=np.array([[10,15,8,12],[5,7,4,6],[2,3,2,4]])

# %%
print(a.ndim)
print(b.ndim)
print(a.shape)
print(b.shape)
# Out:
# 1
# 2
# (3,)
# (3, 4)

# %%
c=(b+2)

# %%
c
# Out:
# array([[12, 17, 10, 14],
#        [ 7,  9,  6,  8],
#        [ 4,  5,  4,  6]])

# %%
d=np.dot(a,c)

# %%
d
# Out:
# array([59000, 77500, 53000, 75000])

# %%
e=np.sqrt(d)

# %%
e
# Out:
# array([242.89915603, 278.38821814, 230.21728866, 273.86127875])

# %% [markdown]
# Slicing and Indexing

# %%
print(b[0,:])
# Out:
# [10 15  8 12]

# %%
print(b[:,0])
print(b[:,1])
# Out:
# [10  5  2]
# [15  7  3]

# %% [markdown]
# Q -access the sales of speakers on thursday and using slicing extarct 2*2 sub array representing the sales of headphones adn smartwatches on monday

# %%
print(b[0,3])
print(b[1:,0:2])
# Out:
# 12
# [[5 7]
#  [2 3]]

# %% [markdown]
# Q- flatten 3X4 daily sales into 1d array of 12 element using .reshape().
# Convert sales data into 2X6 matrix
# use np.linspace to create array of 10 equal intervals between 0 and 100 represent discount percentage

# %%
print(b.reshape(1,12))
print(b.reshape(2,6))
# Out:
# [[10 15  8 12  5  7  4  6  2  3  2  4]]
# [[10 15  8 12  5  7]
#  [ 4  6  2  3  2  4]]

# %%
print(np.linspace(0,100,10))
# Out:
# [  0.          11.11111111  22.22222222  33.33333333  44.44444444
#   55.55555556  66.66666667  77.77777778  88.88888889 100.        ]

# %%
np.random.randint(0,20,size=(3,4))
# Out:
# array([[17,  1,  0,  0],
#        [ 4,  4,  5,  9],
#        [15,  4, 12, 10]], dtype=int32)

# %%
np.random.rand(5)
# Out:
# array([0.70747817, 0.3027666 , 0.85317808, 0.68002258, 0.57487193])

# %% [markdown]
# Use of np.sum() to find the sales

# %%
np.sum(b)
# Out:
# np.int64(78)

# %%
b.sum(axis=1)
# Out:
# array([45, 22, 11])

# %% [markdown]
# Axis in Numpy

# %%
arr=np.array([[1,2,3],[4,5,6]])
print(arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(np.sum(arr,axis=0))
print(np.sum(arr,axis=1))
# Out:
# [5 7 9]
# [ 6 15]

# %% [markdown]
# Where in Numpy

# %%
arr=np.array([10,-5,20,-15])
result=np.where(arr<0,0,arr)
result
# Out:
# array([10,  0, 20,  0])

# %%
arr=np.array([1,2,3,4,5])

# %%
result=np.where(arr%2!=0,-1,arr)
print(result)
# Out:
# [-1  2 -1  4 -1]

# %%
marks=np.array([45,78,32,90,55])

# %%
status=np.where(marks>=50,"Pass","Fail")
print(status)
# Out:
# ['Fail' 'Pass' 'Fail' 'Pass' 'Pass']

# %%
data=np.array([10,20,30,40,50])
mean_val=np.mean(data)
result=np.where(data>mean_val,mean_val,data)
print(result)
# Out:
# [10. 20. 30. 30. 30.]

# %% [markdown]
# Applying Where Condition in 2D Array

# %%
mat=np.array([
    [10,60,30],
    [80,20,90]])
result=np.where(mat>=50,1,0)
print(result)
# Out:
# [[0 1 0]
#  [1 0 1]]
