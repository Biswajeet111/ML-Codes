# %%
import numpy as np

# %%
marks=np.array([[78,85,90],[45,60,55],[88,92,95],[30,40,35],[65,70,75]])

# %%
print(marks.shape)
print(marks.dtype)
print(marks.size)
# Out:
# (5, 3)
# int64
# 15

# %%
print(marks[1,:])
# Out:
# [45 60 55]

# %%
print(marks[:,2])
# Out:
# [90 55 95 35 75]

# %%
print(marks[0,1])
# Out:
# 85
