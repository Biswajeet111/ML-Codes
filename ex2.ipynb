# %%
import numpy as np

# %%
marks=np.array([[78,85,90],[45,60,55],[88,92,95],[30,40,35],[65,70,75]])

# %%
print(marks.shape)
print(marks.dtype)
print(marks.size)
# Out:
# (5, 3)
# int64
# 15

# %%
print(marks[1,:])
# Out:
# [45 60 55]

# %%
print(marks[:,2])
# Out:
# [90 55 95 35 75]

# %%
print(marks[0,1])
# Out:
# 85

# %% [markdown]
# ## task B

# %%
avg_marks=np.mean(marks,axis=1)
print(avg_marks)
# Out:
# [84.33333333 53.33333333 91.66666667 35.         70.        ]

# %%
avg_marks1 = np.mean(marks, axis=0)
print(avg_marks1)
# Out:
# [61.2 69.4 70. ]

# %%
check=np.where(avg_marks>=80,avg_marks,0)
print(check)
# Out:
# [84.33333333  0.         91.66666667  0.          0.        ]

# %%
new=(marks+5)
print(new)
# Out:
# [[ 83  90  95]
#  [ 50  65  60]
#  [ 93  97 100]
#  [ 35  45  40]
#  [ 70  75  80]]

# %% [markdown]
# ## Task C

# %%
check=np.where(marks>=50,1,0)
print(check)
# Out:
# [[1 1 1]
#  [0 1 1]
#  [1 1 1]
#  [0 0 0]
#  [1 1 1]]

# %%
new=np.where(marks<40,0,marks)

# %%
print(new)
# Out:
# [[78 85 90]
#  [45 60 55]
#  [88 92 95]
#  [ 0 40  0]
#  [65 70 75]]

# %% [markdown]
# ## Task D

# %%
new_marks=np.where(avg_marks>=80,'Grade A',np.where(avg_marks>=70,'Grade B',np.where(avg_marks>=50,'Grade C',np.where(avg_marks<50,'No Grade',''))))

# %%
print(new_marks)
# Out:
# ['Grade A' 'Grade C' 'Grade A' 'No Grade' 'Grade B']

# %% [markdown]
# # task E

# %%
new1=marks.copy()

# %%
new1[0,0]=0

# %%
print(new1)
print(marks)
# Out:
# [[ 0 85 90]
#  [45 60 55]
#  [88 92 95]
#  [30 40 35]
#  [65 70 75]]
# [[75 85 90]
#  [45 60 55]
#  [88 92 95]
#  [30 40 35]
#  [65 70 75]]
